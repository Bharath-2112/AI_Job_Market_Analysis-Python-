# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import iplot

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
job = pd.read_csv('ai_job_market_insights.csv')

# %%
job.head()
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
# 2          AI Researcher     Technology        Large  Singapore
# 3          Sales Manager         Retail        Small     Berlin
# 4  Cybersecurity Analyst  Entertainment        Small      Tokyo
#
#   AI_Adoption_Level Automation_Risk     Required_Skills    Salary_USD  \
# 0            Medium            High        UX/UI Design  111392.16520
# 1            Medium            High           Marketing   93792.56247
# 2            Medium            High        UX/UI Design  107170.26310
# 3               Low            High  Project Management   93027.95376
# 4               Low             Low          JavaScript   87752.92217
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No               Decline
# 2             Yes                Growth
# 3              No                Growth
# 4             Yes               Decline

# %%
job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Job_Title              500 non-null    object
#  1   Industry               500 non-null    object
#  2   Company_Size           500 non-null    object
#  3   Location               500 non-null    object
#  4   AI_Adoption_Level      500 non-null    object
#  5   Automation_Risk        500 non-null    object
#  6   Required_Skills        500 non-null    object
#  7   Salary_USD             500 non-null    float64
#  8   Remote_Friendly        500 non-null    object
#  9   Job_Growth_Projection  500 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 39.2+ KB

# %%
job.columns.tolist()
# Out:
# ['Job_Title',
#  'Industry',
#  'Company_Size',
#  'Location',
#  'AI_Adoption_Level',
#  'Automation_Risk',
#  'Required_Skills',
#  'Salary_USD',
#  'Remote_Friendly',
#  'Job_Growth_Projection']

# %%
job.describe()
# Out:
#           Salary_USD
# count     500.000000
# mean    91222.390973
# std     20504.291452
# min     31969.526350
# 25%     78511.514860
# 50%     91998.195285
# 75%    103971.282075
# max    155209.821600

# %%
print(f"Dataset rows = {job.shape[0]}") 
print(f"Dataset rcolumns = {job.shape[1]}")
# Out:
# Dataset rows = 500
# Dataset rcolumns = 10

# %%
job.duplicated().sum()
# Out:
# 0

# %%
#job_title

# %%
print(f"Number of jobs : {len(job.Job_Title.unique())}")
# Out:
# Number of jobs : 10

# %%
job.Job_Title.value_counts()
# Out:
# Job_Title
# Data Scientist           62
# HR Manager               57
# Cybersecurity Analyst    55
# UX Designer              54
# AI Researcher            51
# Sales Manager            49
# Marketing Specialist     48
# Operations Manager       44
# Software Engineer        41
# Product Manager          39
# Name: count, dtype: int64

# %%
iplot(px.bar(job.Job_Title.value_counts() , text_auto=True))

# %%
#Industry

# %%
print(f"Number of industries = {len(job.Industry.unique())}")
# Out:
# Number of industries = 10

# %%
job.Industry.value_counts()
# Out:
# Industry
# Manufacturing         58
# Education             57
# Technology            56
# Telecommunications    53
# Finance               53
# Energy                49
# Entertainment         47
# Retail                46
# Healthcare            42
# Transportation        39
# Name: count, dtype: int64

# %%
iplot(px.bar(job.Industry.value_counts() , text_auto=True))

# %%
iplot(px.bar(job.Industry.value_counts() , text_auto=True))

# %%
plt.figure(figsize = (10,8)) 
color_palette = sns.color_palette('bright') 
plt.pie(job.Company_Size.value_counts() , 
labels = job.Company_Size.value_counts().index , 
autopct = '%0.2f%%', 
colors = color_palette) 
plt.title('Company Size of Dataset') 
plt.legend(title='Company_Size' , bbox_to_anchor=(1.3,1)) 
plt.show()

# %%
#Location

# %%
job.Location.value_counts()
# Out:
# Location
# San Francisco    62
# Singapore        54
# Sydney           52
# Dubai            51
# Tokyo            51
# New York         49
# Berlin           48
# London           46
# Paris            46
# Toronto          41
# Name: count, dtype: int64

# %%
#JOB_TITLE AND INDUSTRY

# %%
cross_job_title_industry = pd.crosstab(job.Job_Title , job.Industry) 
cross_job_title_industry
# Out:
# Industry               Education  Energy  Entertainment  Finance  Healthcare  \
# Job_Title
# AI Researcher                  7       5              3        7           2
# Cybersecurity Analyst          7       5              8        2           8
# Data Scientist                 8       5              8        4           3
# HR Manager                     6       7              6       11           2
# Marketing Specialist           4       6              3        6           5
# Operations Manager             4       5              6        4           6
# Product Manager                5       4              3        7           3
# Sales Manager                  4       5              3        6           4
# Software Engineer              2       1              3        3           4
# UX Designer                   10       6              4        3           5
#
# Industry               Manufacturing  Retail  Technology  Telecommunications  \
# Job_Title
# AI Researcher                      6       6           6                   2
# Cybersecurity Analyst              6       3           6                   7
# Data Scientist                     6       3          10                  10
# HR Manager                         6       6           5                   6
# Marketing Specialist               6       9           5                   3
# Operations Manager                 3       1           8                   3
# Product Manager                    3       1           4                   5
# Sales Manager                      9       5           3                   5
# Software Engineer                  6       5           5                   7
# UX Designer                        7       7           4                   5
#
# Industry               Transportation
# Job_Title
# AI Researcher                       7
# Cybersecurity Analyst               3
# Data Scientist                      5
# HR Manager                          2
# Marketing Specialist                1
# Operations Manager                  4
# Product Manager                     4
# Sales Manager                       5
# Software Engineer                   5
# UX Designer                         3

# %%
# WHAT IS 5 MOST IN DEMAND JOBS IN EVERY INDUSTRY

# %%
for industry in cross_job_title_industry.columns.tolist(): 
    print(f"The 5 most in-demand jobs in ({industry}) : ") 
    print(cross_job_title_industry[industry].nlargest()) 
    iplot(px.bar(cross_job_title_industry[industry].nlargest() , text_auto=True))
# Out:
# The 5 most in-demand jobs in (Education) :
# Job_Title
# UX Designer              10
# Data Scientist            8
# AI Researcher             7
# Cybersecurity Analyst     7
# HR Manager                6
# Name: Education, dtype: int64
# The 5 most in-demand jobs in (Energy) :
# Job_Title
# HR Manager               7
# Marketing Specialist     6
# UX Designer              6
# AI Researcher            5
# Cybersecurity Analyst    5
# Name: Energy, dtype: int64
# The 5 most in-demand jobs in (Entertainment) :
# Job_Title
# Cybersecurity Analyst    8
# Data Scientist           8
# HR Manager               6
# Operations Manager       6
# UX Designer              4
# Name: Entertainment, dtype: int64
# The 5 most in-demand jobs in (Finance) :
# Job_Title
# HR Manager              11
# AI Researcher            7
# Product Manager          7
# Marketing Specialist     6
# Sales Manager            6
# Name: Finance, dtype: int64
# The 5 most in-demand jobs in (Healthcare) :
# Job_Title
# Cybersecurity Analyst    8
# Operations Manager       6
# Marketing Specialist     5
# UX Designer              5
# Sales Manager            4
# Name: Healthcare, dtype: int64
# The 5 most in-demand jobs in (Manufacturing) :
# Job_Title
# Sales Manager            9
# UX Designer              7
# AI Researcher            6
# Cybersecurity Analyst    6
# Data Scientist           6
# Name: Manufacturing, dtype: int64
# The 5 most in-demand jobs in (Retail) :
# Job_Title
# Marketing Specialist    9
# UX Designer             7
# AI Researcher           6
# HR Manager              6
# Sales Manager           5
# Name: Retail, dtype: int64
# The 5 most in-demand jobs in (Technology) :
# Job_Title
# Data Scientist           10
# Operations Manager        8
# AI Researcher             6
# Cybersecurity Analyst     6
# HR Manager                5
# Name: Technology, dtype: int64
# The 5 most in-demand jobs in (Telecommunications) :
# Job_Title
# Data Scientist           10
# Cybersecurity Analyst     7
# Software Engineer         7
# HR Manager                6
# Product Manager           5
# Name: Telecommunications, dtype: int64
# The 5 most in-demand jobs in (Transportation) :
# Job_Title
# AI Researcher         7
# Data Scientist        5
# Sales Manager         5
# Software Engineer     5
# Operations Manager    4
# Name: Transportation, dtype: int64

# %%
# WHAT IS 5 INDUSTRIES MOST INN DEMAND FOR EACH JOB

# %%
for job_name in cross_job_title_industry.index.tolist(): 
   print(f"The 5 industries most in demand for ({job_name}) : ") 
   print(cross_job_title_industry.loc[job_name].nlargest()) 
   iplot(px.bar(cross_job_title_industry.loc[job_name].nlargest() , text_auto=True))
# Out:
# The 5 industries most in demand for (AI Researcher) :
# Industry
# Education         7
# Finance           7
# Transportation    7
# Manufacturing     6
# Retail            6
# Name: AI Researcher, dtype: int64
# The 5 industries most in demand for (Cybersecurity Analyst) :
# Industry
# Entertainment         8
# Healthcare            8
# Education             7
# Telecommunications    7
# Manufacturing         6
# Name: Cybersecurity Analyst, dtype: int64
# The 5 industries most in demand for (Data Scientist) :
# Industry
# Technology            10
# Telecommunications    10
# Education              8
# Entertainment          8
# Manufacturing          6
# Name: Data Scientist, dtype: int64
# The 5 industries most in demand for (HR Manager) :
# Industry
# Finance          11
# Energy            7
# Education         6
# Entertainment     6
# Manufacturing     6
# Name: HR Manager, dtype: int64
# The 5 industries most in demand for (Marketing Specialist) :
# Industry
# Retail           9
# Energy           6
# Finance          6
# Manufacturing    6
# Healthcare       5
# Name: Marketing Specialist, dtype: int64
# The 5 industries most in demand for (Operations Manager) :
# Industry
# Technology       8
# Entertainment    6
# Healthcare       6
# Energy           5
# Education        4
# Name: Operations Manager, dtype: int64
# The 5 industries most in demand for (Product Manager) :
# Industry
# Finance               7
# Education             5
# Telecommunications    5
# Energy                4
# Technology            4
# Name: Product Manager, dtype: int64
# The 5 industries most in demand for (Sales Manager) :
# Industry
# Manufacturing         9
# Finance               6
# Energy                5
# Retail                5
# Telecommunications    5
# Name: Sales Manager, dtype: int64
# The 5 industries most in demand for (Software Engineer) :
# Industry
# Telecommunications    7
# Manufacturing         6
# Retail                5
# Technology            5
# Transportation        5
# Name: Software Engineer, dtype: int64
# The 5 industries most in demand for (UX Designer) :
# Industry
# Education        10
# Manufacturing     7
# Retail            7
# Energy            6
# Healthcare        5
# Name: UX Designer, dtype: int64

# %%
# The most in-demand places for each job

# %%
cross_job_title_location = pd.crosstab(job.Job_Title , job.Location) 
cross_job_title_location
# Out:
# Location               Berlin  Dubai  London  New York  Paris  San Francisco  \
# Job_Title
# AI Researcher               2      3       3         6      2             10
# Cybersecurity Analyst       7      9       8         6      4              4
# Data Scientist              7      6       5         8      4              6
# HR Manager                  5      4       8         6      8              7
# Marketing Specialist        6      5       4         2      6              9
# Operations Manager          7      6       5         4      2              7
# Product Manager             4      2       3         2      4              6
# Sales Manager               5      3       6         3      5              5
# Software Engineer           2      5       3         5      4              3
# UX Designer                 3      8       1         7      7              5
#
# Location               Singapore  Sydney  Tokyo  Toronto
# Job_Title
# AI Researcher                  8       5      5        7
# Cybersecurity Analyst          3       7      3        4
# Data Scientist                 5       8      8        5
# HR Manager                     6       3      5        5
# Marketing Specialist           6       3      6        1
# Operations Manager             4       4      4        1
# Product Manager                3       5      5        5
# Sales Manager                  7       5      3        7
# Software Engineer              6       6      5        2
# UX Designer                    6       6      7        4

# %%
# JOB TITLE AND LOCATION

# %%
for location in cross_job_title_location.columns.tolist(): 
    print(f"The most in-demand places for ({location}) : ") 
    print(cross_job_title_location[location].nlargest()) 
    iplot(px.bar(cross_job_title_location[location].nlargest() , text_auto=True))
# Out:
# The most in-demand places for (Berlin) :
# Job_Title
# Cybersecurity Analyst    7
# Data Scientist           7
# Operations Manager       7
# Marketing Specialist     6
# HR Manager               5
# Name: Berlin, dtype: int64
# The most in-demand places for (Dubai) :
# Job_Title
# Cybersecurity Analyst    9
# UX Designer              8
# Data Scientist           6
# Operations Manager       6
# Marketing Specialist     5
# Name: Dubai, dtype: int64
# The most in-demand places for (London) :
# Job_Title
# Cybersecurity Analyst    8
# HR Manager               8
# Sales Manager            6
# Data Scientist           5
# Operations Manager       5
# Name: London, dtype: int64
# The most in-demand places for (New York) :
# Job_Title
# Data Scientist           8
# UX Designer              7
# AI Researcher            6
# Cybersecurity Analyst    6
# HR Manager               6
# Name: New York, dtype: int64
# The most in-demand places for (Paris) :
# Job_Title
# HR Manager               8
# UX Designer              7
# Marketing Specialist     6
# Sales Manager            5
# Cybersecurity Analyst    4
# Name: Paris, dtype: int64
# The most in-demand places for (San Francisco) :
# Job_Title
# AI Researcher           10
# Marketing Specialist     9
# HR Manager               7
# Operations Manager       7
# Data Scientist           6
# Name: San Francisco, dtype: int64
# The most in-demand places for (Singapore) :
# Job_Title
# AI Researcher           8
# Sales Manager           7
# HR Manager              6
# Marketing Specialist    6
# Software Engineer       6
# Name: Singapore, dtype: int64
# The most in-demand places for (Sydney) :
# Job_Title
# Data Scientist           8
# Cybersecurity Analyst    7
# Software Engineer        6
# UX Designer              6
# AI Researcher            5
# Name: Sydney, dtype: int64
# The most in-demand places for (Tokyo) :
# Job_Title
# Data Scientist          8
# UX Designer             7
# Marketing Specialist    6
# AI Researcher           5
# HR Manager              5
# Name: Tokyo, dtype: int64
# The most in-demand places for (Toronto) :
# Job_Title
# AI Researcher      7
# Sales Manager      7
# Data Scientist     5
# HR Manager         5
# Product Manager    5
# Name: Toronto, dtype: int64

# %%
for job_name in cross_job_title_location.index.tolist(): 
   print(f"The most in-demand job for ({job_name}) : ") 
   print(cross_job_title_location.loc[job_name].nlargest()) 
   iplot(px.bar(cross_job_title_location.loc[job_name].nlargest() , text_auto=True))
# Out:
# The most in-demand job for (AI Researcher) :
# Location
# San Francisco    10
# Singapore         8
# Toronto           7
# New York          6
# Sydney            5
# Name: AI Researcher, dtype: int64
# The most in-demand job for (Cybersecurity Analyst) :
# Location
# Dubai       9
# London      8
# Berlin      7
# Sydney      7
# New York    6
# Name: Cybersecurity Analyst, dtype: int64
# The most in-demand job for (Data Scientist) :
# Location
# New York    8
# Sydney      8
# Tokyo       8
# Berlin      7
# Dubai       6
# Name: Data Scientist, dtype: int64
# The most in-demand job for (HR Manager) :
# Location
# London           8
# Paris            8
# San Francisco    7
# New York         6
# Singapore        6
# Name: HR Manager, dtype: int64
# The most in-demand job for (Marketing Specialist) :
# Location
# San Francisco    9
# Berlin           6
# Paris            6
# Singapore        6
# Tokyo            6
# Name: Marketing Specialist, dtype: int64
# The most in-demand job for (Operations Manager) :
# Location
# Berlin           7
# San Francisco    7
# Dubai            6
# London           5
# New York         4
# Name: Operations Manager, dtype: int64
# The most in-demand job for (Product Manager) :
# Location
# San Francisco    6
# Sydney           5
# Tokyo            5
# Toronto          5
# Berlin           4
# Name: Product Manager, dtype: int64
# The most in-demand job for (Sales Manager) :
# Location
# Singapore    7
# Toronto      7
# London       6
# Berlin       5
# Paris        5
# Name: Sales Manager, dtype: int64
# The most in-demand job for (Software Engineer) :
# Location
# Singapore    6
# Sydney       6
# Dubai        5
# New York     5
# Tokyo        5
# Name: Software Engineer, dtype: int64
# The most in-demand job for (UX Designer) :
# Location
# Dubai        8
# New York     7
# Paris        7
# Tokyo        7
# Singapore    6
# Name: UX Designer, dtype: int64

# %%
# Job_Title & Required_Skills
what is skills required for each job ?

# %%
job_title_group = job.groupby('Job_Title') 
for job_name in job.Job_Title.unique(): 
   print(f"Skills required for *({job_name})* is : ") 
   print(f"{job_title_group.get_group(job_name)['Required_Skills'].unique().tolist()}\n") 
   print('-----------------------------------------------------------------------------')
# Out:
# Skills required for *(Cybersecurity Analyst)* is :
# ['UX/UI Design', 'JavaScript', 'Machine Learning', 'Marketing', 'Project Management', 'Cybersecurity', 'Sales', 'Python', 'Communication', 'Data Analysis']
#
# -----------------------------------------------------------------------------
# Skills required for *(Marketing Specialist)* is :
# ['Marketing', 'Python', 'Machine Learning', 'UX/UI Design', 'JavaScript', 'Sales', 'Project Management', 'Cybersecurity', 'Communication', 'Data Analysis']
#
# -----------------------------------------------------------------------------
# Skills required for *(AI Researcher)* is :
# ['UX/UI Design', 'JavaScript', 'Python', 'Project Management', 'Marketing', 'Communication', 'Sales', 'Machine Learning', 'Cybersecurity', 'Data Analysis']
#
# -----------------------------------------------------------------------------
# Skills required for *(Sales Manager)* is :
# ['Project Management', 'Cybersecurity', 'UX/UI Design', 'JavaScript', 'Machine Learning', 'Data Analysis', 'Python', 'Communication', 'Marketing', 'Sales']
#
# -----------------------------------------------------------------------------
# Skills required for *(UX Designer)* is :
# ['Cybersecurity', 'UX/UI Design', 'JavaScript', 'Python', 'Project Management', 'Marketing', 'Machine Learning', 'Communication', 'Sales', 'Data Analysis']
#
# -----------------------------------------------------------------------------
# Skills required for *(HR Manager)* is :
# ['Sales', 'Cybersecurity', 'Data Analysis', 'Machine Learning', 'Communication', 'Python', 'Marketing', 'UX/UI Design', 'Project Management', 'JavaScript']
#
# -----------------------------------------------------------------------------
# Skills required for *(Product Manager)* is :
# ['JavaScript', 'UX/UI Design', 'Data Analysis', 'Cybersecurity', 'Machine Learning', 'Python', 'Project Management', 'Marketing', 'Sales', 'Communication']
#
# -----------------------------------------------------------------------------
# Skills required for *(Software Engineer)* is :
# ['Machine Learning', 'UX/UI Design', 'Python', 'Cybersecurity', 'Project Management', 'Sales', 'JavaScript', 'Communication', 'Data Analysis', 'Marketing']
#
# -----------------------------------------------------------------------------
# Skills required for *(Data Scientist)* is :
# ['JavaScript', 'Sales', 'Marketing', 'Data Analysis', 'Cybersecurity', 'UX/UI Design', 'Python', 'Communication', 'Project Management', 'Machine Learning']
#
# -----------------------------------------------------------------------------
# Skills required for *(Operations Manager)* is :
# ['UX/UI Design', 'Project Management', 'Machine Learning', 'Python', 'Cybersecurity', 'Sales', 'JavaScript', 'Communication', 'Data Analysis', 'Marketing']
#
# -----------------------------------------------------------------------------

# %%
# Job_Title & Salary_USD

# %%
plt.figure(figsize=(12,6)) 
sns.histplot(job.Salary_USD , kde=True)
# Out:
# <Axes: xlabel='Salary_USD', ylabel='Count'>

# %%
job_title_location_group = job.groupby(['Location' , 'Job_Title']) 
for location in job.Location.unique(): 
  for job_name in job.Job_Title.unique(): 
     print(f"Salary_USD in ({location}) for ({job_name})") 
     print(job_title_location_group.get_group((location,job_name)).Salary_USD.describe()[['mean' , 'min' , 'max']]) 
     print('-------------------------------\n') 
     print('****************************************************\n****************************************************')
# Out:
# Salary_USD in (Dubai) for (Cybersecurity Analyst)
# mean     89324.862056
# min      51676.656410
# max     111392.165200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Dubai) for (Marketing Specialist)
# mean     87012.48275
# min      50286.75687
# max     109663.04420
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Dubai) for (AI Researcher)
# mean     96047.839837
# min      67469.063750
# max     126266.824100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Dubai) for (Sales Manager)
# mean     85412.358477
# min      70845.835020
# max     102591.882700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Dubai) for (UX Designer)
# mean     96664.851767
# min      58580.132890
# max     123992.648300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Dubai) for (HR Manager)
# mean     90153.398215
# min      56461.830520
# max     116994.790600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Dubai) for (Product Manager)
# mean    62307.245515
# min     42486.679780
# max     82127.811250
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Dubai) for (Software Engineer)
# mean     82956.57972
# min      73638.27901
# max     104018.51430
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Dubai) for (Data Scientist)
# mean     81342.834977
# min      48518.480800
# max     104261.223600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Dubai) for (Operations Manager)
# mean     89626.942832
# min      46705.714990
# max     110679.265100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Singapore) for (Cybersecurity Analyst)
# mean     96558.428627
# min      80411.505170
# max     118489.240300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Singapore) for (Marketing Specialist)
# mean     99547.304878
# min      93792.562470
# max     104854.999200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Singapore) for (AI Researcher)
# mean     91007.02917
# min      72700.98697
# max     107170.26310
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Singapore) for (Sales Manager)
# mean    103517.757664
# min      92037.214130
# max     116857.484300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Singapore) for (UX Designer)
# mean     85524.632915
# min      35963.297320
# max     117490.669100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Singapore) for (HR Manager)
# mean     83990.607387
# min      54010.721370
# max     102065.720700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Singapore) for (Product Manager)
# mean    100338.803377
# min      99311.680330
# max     101001.901100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Singapore) for (Software Engineer)
# mean     88255.852818
# min      61884.905390
# max     138448.110800
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Singapore) for (Data Scientist)
# mean     88972.46662
# min      67722.93801
# max     130007.35020
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Singapore) for (Operations Manager)
# mean    107451.156225
# min     102574.317200
# max     119395.978500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Berlin) for (Cybersecurity Analyst)
# mean     80008.563481
# min      33601.381360
# max     101820.431100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Berlin) for (Marketing Specialist)
# mean     85124.598643
# min      60768.876450
# max     113976.705900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Berlin) for (AI Researcher)
# mean    106177.2685
# min      97115.8595
# max     115238.6775
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Berlin) for (Sales Manager)
# mean     81473.389152
# min      55906.059730
# max     101953.052900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Berlin) for (UX Designer)
# mean    106557.980923
# min      93313.178870
# max     116207.694000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Berlin) for (HR Manager)
# mean    80928.784626
# min     68764.378920
# max     95217.781290
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Berlin) for (Product Manager)
# mean     95791.163733
# min      78981.776350
# max     127413.267500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Berlin) for (Software Engineer)
# mean     88666.18991
# min      63064.75182
# max     114267.62800
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Berlin) for (Data Scientist)
# mean     96716.112314
# min      73692.802190
# max     105821.394000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Berlin) for (Operations Manager)
# mean    117597.286186
# min     101019.733200
# max     139078.066900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Tokyo) for (Cybersecurity Analyst)
# mean    83577.686223
# min     66782.590810
# max     96197.545690
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Tokyo) for (Marketing Specialist)
# mean     87283.55385
# min      48773.49088
# max     117295.97620
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Tokyo) for (AI Researcher)
# mean     91198.282378
# min      72034.125080
# max     117936.964000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Tokyo) for (Sales Manager)
# mean    81925.158063
# min     61109.653260
# max     97622.960930
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Tokyo) for (UX Designer)
# mean     95823.340774
# min      41495.714440
# max     126678.453000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Tokyo) for (HR Manager)
# mean     92194.55749
# min      73323.29633
# max     118980.60460
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Tokyo) for (Product Manager)
# mean    108724.812218
# min      70448.757490
# max     133106.655000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Tokyo) for (Software Engineer)
# mean     87434.020896
# min      74201.479490
# max     100930.452600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Tokyo) for (Data Scientist)
# mean     97886.150214
# min      65884.757430
# max     127434.956400
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Tokyo) for (Operations Manager)
# mean     91475.859695
# min      68850.576160
# max     111189.610600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (San Francisco) for (Cybersecurity Analyst)
# mean     90390.350685
# min      47132.653520
# max     135566.660600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (San Francisco) for (Marketing Specialist)
# mean    101214.124778
# min      43343.243990
# max     155209.821600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (San Francisco) for (AI Researcher)
# mean     92792.242144
# min      71211.884320
# max     119961.891300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (San Francisco) for (Sales Manager)
# mean    102949.289536
# min      86529.363420
# max     124900.328600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (San Francisco) for (UX Designer)
# mean     84453.793698
# min      41396.157460
# max     102825.007900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (San Francisco) for (HR Manager)
# mean     96731.106329
# min      67257.172390
# max     135778.949800
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (San Francisco) for (Product Manager)
# mean    69499.083225
# min     41298.726200
# max     97645.098780
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (San Francisco) for (Software Engineer)
# mean    74189.902973
# min     56076.418650
# max     85332.654220
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (San Francisco) for (Data Scientist)
# mean     87765.530672
# min      47666.724780
# max     119717.365500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (San Francisco) for (Operations Manager)
# mean     76342.73830
# min      41810.51358
# max     112988.46870
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (London) for (Cybersecurity Analyst)
# mean     95052.685713
# min      76583.279270
# max     125455.823500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (London) for (Marketing Specialist)
# mean     86597.488952
# min      74286.408070
# max     105559.095500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (London) for (AI Researcher)
# mean    80025.033073
# min     71529.492160
# max     93529.746210
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (London) for (Sales Manager)
# mean     88618.04963
# min      75497.33813
# max     114957.91920
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (London) for (UX Designer)
# mean    53276.51071
# min     53276.51071
# max     53276.51071
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (London) for (HR Manager)
# mean     96963.955975
# min      46867.986070
# max     126849.580900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (London) for (Product Manager)
# mean     86420.23411
# min      58864.73308
# max     114751.44090
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (London) for (Software Engineer)
# mean    75186.965093
# min     62093.325470
# max     85217.526110
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (London) for (Data Scientist)
# mean     81659.343858
# min      45848.725490
# max     112457.279100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (London) for (Operations Manager)
# mean     96917.925738
# min      59806.144810
# max     116713.117900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Paris) for (Cybersecurity Analyst)
# mean     92639.52558
# min      84587.58841
# max     102593.99710
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Paris) for (Marketing Specialist)
# mean     80136.051162
# min      63848.512320
# max     109060.482900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Paris) for (AI Researcher)
# mean     95430.593855
# min      80562.808110
# max     110298.379600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Paris) for (Sales Manager)
# mean    103413.544752
# min      73376.602280
# max     129306.829200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Paris) for (UX Designer)
# mean     85642.327354
# min      49877.395940
# max     103239.911300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Paris) for (HR Manager)
# mean     92172.798602
# min      55015.599140
# max     112822.654600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Paris) for (Product Manager)
# mean     93180.25275
# min      83940.88924
# max     114893.76090
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Paris) for (Software Engineer)
# mean     94990.469217
# min      77222.769440
# max     103180.627000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Paris) for (Data Scientist)
# mean    105615.445562
# min      67371.727770
# max     148467.112300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Paris) for (Operations Manager)
# mean    83015.556395
# min     77642.150630
# max     88388.962160
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Sydney) for (Cybersecurity Analyst)
# mean     91946.781413
# min      76744.303970
# max     121897.107000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Sydney) for (Marketing Specialist)
# mean    83799.62212
# min     74146.11436
# max     90541.08081
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Sydney) for (AI Researcher)
# mean    102563.465086
# min      83543.510730
# max     119754.540700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Sydney) for (Sales Manager)
# mean     97552.539552
# min      78953.566530
# max     134822.691400
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Sydney) for (UX Designer)
# mean     99833.472592
# min      85073.804890
# max     140475.995800
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Sydney) for (HR Manager)
# mean    72126.79255
# min     58952.45077
# max     82049.40358
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Sydney) for (Product Manager)
# mean     92046.399272
# min      66566.602840
# max     124041.103100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Sydney) for (Software Engineer)
# mean     76248.331343
# min      45186.524270
# max     107677.224100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Sydney) for (Data Scientist)
# mean     96426.711421
# min      57499.280620
# max     129631.583300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Sydney) for (Operations Manager)
# mean     94479.520747
# min      78391.663060
# max     126752.134700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (New York) for (Cybersecurity Analyst)
# mean    85540.969352
# min     68665.577820
# max     98235.725820
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (New York) for (Marketing Specialist)
# mean    109080.52755
# min     107067.72890
# max     111093.32620
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (New York) for (AI Researcher)
# mean     98826.716483
# min      74057.145510
# max     117752.886100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (New York) for (Sales Manager)
# mean     91603.053227
# min      82709.017070
# max     100249.330300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (New York) for (UX Designer)
# mean    80906.951684
# min     63245.811520
# max     90053.706820
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (New York) for (HR Manager)
# mean    90445.950523
# min     61369.640050
# max     99829.501270
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (New York) for (Product Manager)
# mean    113900.924595
# min      98828.429990
# max     128973.419200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (New York) for (Software Engineer)
# mean     95879.009068
# min      84124.067000
# max     106800.196500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (New York) for (Data Scientist)
# mean     89680.412871
# min      31969.526350
# max     127392.306600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (New York) for (Operations Manager)
# mean    115600.001548
# min      93969.706390
# max     129293.901000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Toronto) for (Cybersecurity Analyst)
# mean     91198.058417
# min      72671.587770
# max     117188.228400
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Toronto) for (Marketing Specialist)
# mean    91646.59773
# min     91646.59773
# max     91646.59773
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Toronto) for (AI Researcher)
# mean    103652.665823
# min      82792.507070
# max     122683.905300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Toronto) for (Sales Manager)
# mean     84758.208923
# min      60216.997660
# max     121444.843300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Toronto) for (UX Designer)
# mean     87799.639153
# min      71031.102540
# max     100795.605200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Toronto) for (HR Manager)
# mean     81581.938622
# min      65462.489310
# max     100779.559500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Toronto) for (Product Manager)
# mean     90374.675802
# min      53511.182270
# max     110181.305900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Toronto) for (Software Engineer)
# mean    70157.104645
# min     67646.601460
# max     72667.607830
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Toronto) for (Data Scientist)
# mean     86515.373894
# min      72921.205830
# max     104560.977200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Toronto) for (Operations Manager)
# mean    83249.43428
# min     83249.43428
# max     83249.43428
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************

# %%
# Job_Title & Remote_Friendly

# %%
cross_job_title_remote = pd.crosstab(job.Remote_Friendly , job.Job_Title) 
cross_job_title_remote
# Out:
# Job_Title        AI Researcher  Cybersecurity Analyst  Data Scientist  \
# Remote_Friendly
# No                          33                     21              28
# Yes                         18                     34              34
#
# Job_Title        HR Manager  Marketing Specialist  Operations Manager  \
# Remote_Friendly
# No                       23                    23                  25
# Yes                      34                    25                  19
#
# Job_Title        Product Manager  Sales Manager  Software Engineer  \
# Remote_Friendly
# No                            18             19                 24
# Yes                           21             30                 17
#
# Job_Title        UX Designer
# Remote_Friendly
# No                        35
# Yes                       19

# %%
# what is most jobs have Remote_Friendly ?

# %%
print('most jobs have Remote_Friendly : ') 
print(cross_job_title_remote.loc['Yes'].nlargest(5))
# Out:
# most jobs have Remote_Friendly :
# Job_Title
# Cybersecurity Analyst    34
# Data Scientist           34
# HR Manager               34
# Sales Manager            30
# Marketing Specialist     25
# Name: Yes, dtype: int64

# %%
# what is jobs that have Remote_Friendly or verse ?

# %%
for job_name in cross_job_title_remote.columns: 
  if cross_job_title_remote[job_name].loc['Yes'] > cross_job_title_remote[job_name].loc['No']: 
    print(f"{job_name} ---> (Remote Frindely)") 
  else: 
    print(f"{job_name} ---> (Not On-Site Frindely)")
# Out:
# AI Researcher ---> (Not On-Site Frindely)
# Cybersecurity Analyst ---> (Remote Frindely)
# Data Scientist ---> (Remote Frindely)
# HR Manager ---> (Remote Frindely)
# Marketing Specialist ---> (Remote Frindely)
# Operations Manager ---> (Not On-Site Frindely)
# Product Manager ---> (Remote Frindely)
# Sales Manager ---> (Remote Frindely)
# Software Engineer ---> (Not On-Site Frindely)
# UX Designer ---> (Not On-Site Frindely)

# %%
plt.style.use('seaborn-v0_8-bright') 
plt.figure(figsize = (20,10)) 
cross_job_title_remote.T.plot(kind='bar' , width=0.5) 
plt.legend(bbox_to_anchor = (1.3,1)) 
plt.show()

# %%
# Job_Title & Job_Growth_Projection¶

# %%
cross_job_title_growth = pd.crosstab(job.Job_Growth_Projection , job.Job_Title) 
cross_job_title_growth
# Out:
# Job_Title              AI Researcher  Cybersecurity Analyst  Data Scientist  \
# Job_Growth_Projection
# Decline                           16                     19              23
# Growth                            20                     14              22
# Stable                            15                     22              17
#
# Job_Title              HR Manager  Marketing Specialist  Operations Manager  \
# Job_Growth_Projection
# Decline                        22                    23                   7
# Growth                         14                    11                  19
# Stable                         21                    14                  18
#
# Job_Title              Product Manager  Sales Manager  Software Engineer  \
# Job_Growth_Projection
# Decline                             10             16                 12
# Growth                              15             19                 16
# Stable                              14             14                 13
#
# Job_Title              UX Designer
# Job_Growth_Projection
# Decline                         21
# Growth                          19
# Stable                          14

# %%
for job_name in cross_job_title_growth.columns: 
  iplot(px.pie(values = cross_job_title_growth[job_name], 
  title = f"({job_name}) ---> *{cross_job_title_growth[job_name].idxmax()}*" , 
  names = cross_job_title_growth.index).update_traces(textinfo='label+percent'))

# %%
# Job_Title & Job_Growth_Projection & Industry
what is growth rate for each job in each industry ?

# %%
job_title_industry_group = job.groupby(['Job_Title' , 'Industry'])

# %%
for industry in job.Industry.unique(): 
 print(f"in **{industry}**") 
 for job_name in job.Job_Title.unique(): 
   print(f" ({job_name}) ---> {job_title_industry_group.get_group((job_name ,industry)).Job_Growth_Projection.value_counts().idxmax()}") 
 print('\n')
# Out:
# in **Entertainment**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Stable
#  (AI Researcher) ---> Stable
#  (Sales Manager) ---> Decline
#  (UX Designer) ---> Decline
#  (HR Manager) ---> Decline
#  (Product Manager) ---> Growth
#  (Software Engineer) ---> Growth
#  (Data Scientist) ---> Decline
#  (Operations Manager) ---> Growth
#
#
# in **Technology**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Decline
#  (AI Researcher) ---> Growth
#  (Sales Manager) ---> Decline
#  (UX Designer) ---> Stable
#  (HR Manager) ---> Decline
#  (Product Manager) ---> Stable
#  (Software Engineer) ---> Growth
#  (Data Scientist) ---> Decline
#  (Operations Manager) ---> Stable
#
#
# in **Retail**
#  (Cybersecurity Analyst) ---> Growth
#  (Marketing Specialist) ---> Decline
#  (AI Researcher) ---> Stable
#  (Sales Manager) ---> Decline
#  (UX Designer) ---> Stable
#  (HR Manager) ---> Decline
#  (Product Manager) ---> Growth
#  (Software Engineer) ---> Stable
#  (Data Scientist) ---> Stable
#  (Operations Manager) ---> Stable
#
#
# in **Education**
#  (Cybersecurity Analyst) ---> Decline
#  (Marketing Specialist) ---> Decline
#  (AI Researcher) ---> Growth
#  (Sales Manager) ---> Stable
#  (UX Designer) ---> Growth
#  (HR Manager) ---> Stable
#  (Product Manager) ---> Growth
#  (Software Engineer) ---> Growth
#  (Data Scientist) ---> Growth
#  (Operations Manager) ---> Decline
#
#
# in **Finance**
#  (Cybersecurity Analyst) ---> Decline
#  (Marketing Specialist) ---> Growth
#  (AI Researcher) ---> Growth
#  (Sales Manager) ---> Decline
#  (UX Designer) ---> Decline
#  (HR Manager) ---> Growth
#  (Product Manager) ---> Growth
#  (Software Engineer) ---> Growth
#  (Data Scientist) ---> Growth
#  (Operations Manager) ---> Stable
#
#
# in **Transportation**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Stable
#  (AI Researcher) ---> Decline
#  (Sales Manager) ---> Growth
#  (UX Designer) ---> Decline
#  (HR Manager) ---> Stable
#  (Product Manager) ---> Stable
#  (Software Engineer) ---> Growth
#  (Data Scientist) ---> Growth
#  (Operations Manager) ---> Stable
#
#
# in **Telecommunications**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Growth
#  (AI Researcher) ---> Decline
#  (Sales Manager) ---> Growth
#  (UX Designer) ---> Stable
#  (HR Manager) ---> Stable
#  (Product Manager) ---> Stable
#  (Software Engineer) ---> Stable
#  (Data Scientist) ---> Growth
#  (Operations Manager) ---> Growth
#
#
# in **Manufacturing**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Decline
#  (AI Researcher) ---> Decline
#  (Sales Manager) ---> Growth
#  (UX Designer) ---> Growth
#  (HR Manager) ---> Decline
#  (Product Manager) ---> Stable
#  (Software Engineer) ---> Decline
#  (Data Scientist) ---> Growth
#  (Operations Manager) ---> Growth
#
#
# in **Healthcare**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Stable
#  (AI Researcher) ---> Stable
#  (Sales Manager) ---> Growth
#  (UX Designer) ---> Decline
#  (HR Manager) ---> Decline
#  (Product Manager) ---> Stable
#  (Software Engineer) ---> Decline
#  (Data Scientist) ---> Growth
#  (Operations Manager) ---> Growth
#
#
# in **Energy**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Decline
#  (AI Researcher) ---> Growth
#  (Sales Manager) ---> Stable
#  (UX Designer) ---> Growth
#  (HR Manager) ---> Decline
#  (Product Manager) ---> Growth
#  (Software Engineer) ---> Stable
#  (Data Scientist) ---> Decline
#  (Operations Manager) ---> Growth

# %%
# Job_Title & Job_Growth_Projection & Location
what is growth rate for each job in each Location ?

# %%
job_title_location_group = job.groupby(['Job_Title' , 'Location'])

# %%
for location in job.Location.unique(): 
 print(f"in **{location}**") 
 for job_name in job.Job_Title.unique(): 
  print(f" ({job_name}) ---> {job_title_location_group.get_group((job_name ,location)).Job_Growth_Projection.value_counts().idxmax()}") 
 print('\n')
# Out:
# in **Dubai**
#  (Cybersecurity Analyst) ---> Decline
#  (Marketing Specialist) ---> Decline
#  (AI Researcher) ---> Stable
#  (Sales Manager) ---> Growth
#  (UX Designer) ---> Decline
#  (HR Manager) ---> Growth
#  (Product Manager) ---> Decline
#  (Software Engineer) ---> Growth
#  (Data Scientist) ---> Decline
#  (Operations Manager) ---> Stable
#
#
# in **Singapore**
#  (Cybersecurity Analyst) ---> Decline
#  (Marketing Specialist) ---> Decline
#  (AI Researcher) ---> Growth
#  (Sales Manager) ---> Decline
#  (UX Designer) ---> Decline
#  (HR Manager) ---> Growth
#  (Product Manager) ---> Growth
#  (Software Engineer) ---> Decline
#  (Data Scientist) ---> Stable
#  (Operations Manager) ---> Growth
#
#
# in **Berlin**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Decline
#  (AI Researcher) ---> Growth
#  (Sales Manager) ---> Stable
#  (UX Designer) ---> Growth
#  (HR Manager) ---> Decline
#  (Product Manager) ---> Growth
#  (Software Engineer) ---> Stable
#  (Data Scientist) ---> Growth
#  (Operations Manager) ---> Growth
#
#
# in **Tokyo**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Stable
#  (AI Researcher) ---> Growth
#  (Sales Manager) ---> Decline
#  (UX Designer) ---> Growth
#  (HR Manager) ---> Stable
#  (Product Manager) ---> Growth
#  (Software Engineer) ---> Growth
#  (Data Scientist) ---> Growth
#  (Operations Manager) ---> Growth
#
#
# in **San Francisco**
#  (Cybersecurity Analyst) ---> Growth
#  (Marketing Specialist) ---> Decline
#  (AI Researcher) ---> Decline
#  (Sales Manager) ---> Growth
#  (UX Designer) ---> Growth
#  (HR Manager) ---> Decline
#  (Product Manager) ---> Decline
#  (Software Engineer) ---> Growth
#  (Data Scientist) ---> Growth
#  (Operations Manager) ---> Stable
#
#
# in **London**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Decline
#  (AI Researcher) ---> Stable
#  (Sales Manager) ---> Decline
#  (UX Designer) ---> Stable
#  (HR Manager) ---> Stable
#  (Product Manager) ---> Stable
#  (Software Engineer) ---> Growth
#  (Data Scientist) ---> Decline
#  (Operations Manager) ---> Growth
#
#
# in **Paris**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Growth
#  (AI Researcher) ---> Stable
#  (Sales Manager) ---> Decline
#  (UX Designer) ---> Decline
#  (HR Manager) ---> Decline
#  (Product Manager) ---> Stable
#  (Software Engineer) ---> Decline
#  (Data Scientist) ---> Stable
#  (Operations Manager) ---> Stable
#
#
# in **Sydney**
#  (Cybersecurity Analyst) ---> Decline
#  (Marketing Specialist) ---> Growth
#  (AI Researcher) ---> Growth
#  (Sales Manager) ---> Decline
#  (UX Designer) ---> Growth
#  (HR Manager) ---> Stable
#  (Product Manager) ---> Stable
#  (Software Engineer) ---> Stable
#  (Data Scientist) ---> Decline
#  (Operations Manager) ---> Decline
#
#
# in **New York**
#  (Cybersecurity Analyst) ---> Stable
#  (Marketing Specialist) ---> Growth
#  (AI Researcher) ---> Growth
#  (Sales Manager) ---> Growth
#  (UX Designer) ---> Growth
#  (HR Manager) ---> Growth
#  (Product Manager) ---> Stable
#  (Software Engineer) ---> Stable
#  (Data Scientist) ---> Decline
#  (Operations Manager) ---> Stable
#
#
# in **Toronto**
#  (Cybersecurity Analyst) ---> Growth
#  (Marketing Specialist) ---> Decline
#  (AI Researcher) ---> Decline
#  (Sales Manager) ---> Growth
#  (UX Designer) ---> Stable
#  (HR Manager) ---> Decline
#  (Product Manager) ---> Growth
#  (Software Engineer) ---> Decline
#  (Data Scientist) ---> Stable
#  (Operations Manager) ---> Stable

# %%
# Job_Title & Location & Industry
what is job in-demand in each location for each industry ?

# %%
location_indusrty_group = job.groupby([job.Location , job.Industry])

# %%
for location in job.Location.unique(): 
 print(f"in **{location}**") 
 for industry in job.Industry.unique(): 
  print(f" ({industry}) ---> {location_indusrty_group.get_group((location ,industry)).Job_Title.unique().tolist()}") 
 print('\n')
# Out:
# in **Dubai**
#  (Entertainment) ---> ['Cybersecurity Analyst', 'Software Engineer', 'Data Scientist']
#  (Technology) ---> ['Cybersecurity Analyst', 'Operations Manager', 'Software Engineer', 'Product Manager', 'Data Scientist']
#  (Retail) ---> ['UX Designer', 'AI Researcher', 'Software Engineer', 'Marketing Specialist']
#  (Education) ---> ['Operations Manager', 'Marketing Specialist', 'Software Engineer']
#  (Finance) ---> ['UX Designer', 'AI Researcher', 'HR Manager']
#  (Transportation) ---> ['Operations Manager', 'Cybersecurity Analyst', 'Product Manager', 'HR Manager']
#  (Telecommunications) ---> ['Sales Manager', 'Cybersecurity Analyst', 'Data Scientist', 'UX Designer', 'HR Manager']
#  (Manufacturing) ---> ['Data Scientist', 'UX Designer', 'Marketing Specialist']
#  (Healthcare) ---> ['Sales Manager', 'AI Researcher', 'Operations Manager', 'Cybersecurity Analyst', 'UX Designer']
#  (Energy) ---> ['UX Designer', 'Operations Manager', 'Software Engineer', 'Marketing Specialist', 'Cybersecurity Analyst']
#
#
# in **Singapore**
#  (Entertainment) ---> ['Sales Manager', 'AI Researcher', 'UX Designer', 'Product Manager', 'Data Scientist', 'Software Engineer', 'Cybersecurity Analyst']
#  (Technology) ---> ['Marketing Specialist', 'AI Researcher', 'Software Engineer', 'Operations Manager', 'Cybersecurity Analyst', 'UX Designer']
#  (Retail) ---> ['Marketing Specialist', 'Data Scientist', 'HR Manager']
#  (Education) ---> ['HR Manager', 'Cybersecurity Analyst', 'UX Designer', 'Marketing Specialist', 'Sales Manager']
#  (Finance) ---> ['HR Manager', 'Product Manager', 'AI Researcher', 'Software Engineer', 'Data Scientist']
#  (Transportation) ---> ['AI Researcher', 'Operations Manager', 'Marketing Specialist', 'Software Engineer']
#  (Telecommunications) ---> ['Marketing Specialist', 'Data Scientist']
#  (Manufacturing) ---> ['Software Engineer', 'AI Researcher', 'Sales Manager']
#  (Healthcare) ---> ['Sales Manager', 'Product Manager']
#  (Energy) ---> ['HR Manager', 'UX Designer', 'Marketing Specialist', 'Sales Manager', 'Operations Manager', 'AI Researcher']
#
#
# in **Berlin**
#  (Entertainment) ---> ['Cybersecurity Analyst', 'Marketing Specialist', 'Operations Manager', 'HR Manager']
#  (Technology) ---> ['AI Researcher', 'Operations Manager', 'Data Scientist', 'Sales Manager', 'HR Manager']
#  (Retail) ---> ['Sales Manager', 'UX Designer', 'Data Scientist', 'Product Manager', 'Marketing Specialist']
#  (Education) ---> ['Product Manager', 'Sales Manager', 'Marketing Specialist', 'Software Engineer']
#  (Finance) ---> ['Cybersecurity Analyst']
#  (Transportation) ---> ['Data Scientist', 'Product Manager']
#  (Telecommunications) ---> ['Data Scientist', 'UX Designer', 'Software Engineer', 'Marketing Specialist', 'HR Manager', 'Cybersecurity Analyst']
#  (Manufacturing) ---> ['Cybersecurity Analyst', 'AI Researcher', 'Sales Manager', 'Marketing Specialist']
#  (Healthcare) ---> ['Operations Manager', 'Cybersecurity Analyst', 'Data Scientist', 'HR Manager']
#  (Energy) ---> ['Operations Manager', 'HR Manager', 'UX Designer', 'Marketing Specialist', 'Cybersecurity Analyst']
#
#
# in **Tokyo**
#  (Entertainment) ---> ['Cybersecurity Analyst', 'Product Manager', 'Data Scientist', 'Operations Manager', 'HR Manager']
#  (Technology) ---> ['HR Manager', 'Data Scientist', 'Product Manager', 'Marketing Specialist']
#  (Retail) ---> ['UX Designer', 'Marketing Specialist', 'Software Engineer', 'AI Researcher']
#  (Education) ---> ['UX Designer', 'Cybersecurity Analyst', 'AI Researcher', 'Product Manager', 'HR Manager', 'Data Scientist']
#  (Finance) ---> ['Data Scientist', 'Sales Manager', 'Operations Manager', 'Marketing Specialist', 'Product Manager', 'UX Designer', 'HR Manager']
#  (Transportation) ---> ['UX Designer', 'Sales Manager']
#  (Telecommunications) ---> ['Software Engineer', 'Operations Manager', 'Product Manager']
#  (Manufacturing) ---> ['AI Researcher', 'HR Manager', 'Marketing Specialist', 'Software Engineer', 'Sales Manager', 'UX Designer']
#  (Healthcare) ---> ['AI Researcher', 'Operations Manager', 'UX Designer']
#  (Energy) ---> ['Data Scientist', 'AI Researcher', 'Marketing Specialist']
#
#
# in **San Francisco**
#  (Entertainment) ---> ['Operations Manager', 'UX Designer', 'HR Manager']
#  (Technology) ---> ['Data Scientist', 'Marketing Specialist', 'Operations Manager', 'AI Researcher', 'Product Manager', 'HR Manager', 'Sales Manager']
#  (Retail) ---> ['Marketing Specialist', 'Cybersecurity Analyst', 'AI Researcher', 'UX Designer', 'HR Manager']
#  (Education) ---> ['UX Designer', 'Data Scientist', 'Operations Manager', 'AI Researcher']
#  (Finance) ---> ['Product Manager', 'Software Engineer', 'Operations Manager', 'HR Manager', 'Marketing Specialist', 'UX Designer']
#  (Transportation) ---> ['AI Researcher', 'Operations Manager', 'Software Engineer', 'Data Scientist', 'Sales Manager']
#  (Telecommunications) ---> ['Marketing Specialist', 'HR Manager', 'Cybersecurity Analyst', 'AI Researcher', 'Data Scientist']
#  (Manufacturing) ---> ['Sales Manager', 'AI Researcher', 'UX Designer', 'Product Manager', 'Operations Manager']
#  (Healthcare) ---> ['Cybersecurity Analyst', 'Marketing Specialist', 'Product Manager', 'Sales Manager']
#  (Energy) ---> ['AI Researcher', 'Sales Manager', 'Product Manager', 'Cybersecurity Analyst']
#
#
# in **London**
#  (Entertainment) ---> ['Cybersecurity Analyst', 'Operations Manager']
#  (Technology) ---> ['HR Manager', 'Cybersecurity Analyst', 'Operations Manager', 'Data Scientist']
#  (Retail) ---> ['AI Researcher', 'Operations Manager', 'HR Manager', 'UX Designer']
#  (Education) ---> ['AI Researcher', 'Cybersecurity Analyst', 'HR Manager', 'Sales Manager']
#  (Finance) ---> ['Marketing Specialist', 'HR Manager', 'AI Researcher', 'Sales Manager']
#  (Transportation) ---> ['Software Engineer', 'Data Scientist', 'HR Manager']
#  (Telecommunications) ---> ['HR Manager', 'Sales Manager', 'Operations Manager', 'Software Engineer', 'Product Manager', 'Cybersecurity Analyst']
#  (Manufacturing) ---> ['Data Scientist', 'Cybersecurity Analyst', 'Marketing Specialist', 'Sales Manager', 'Operations Manager', 'Software Engineer', 'HR Manager']
#  (Healthcare) ---> ['Product Manager', 'Data Scientist', 'Marketing Specialist']
#  (Energy) ---> ['Sales Manager', 'Product Manager', 'Data Scientist']
#
#
# in **Paris**
#  (Entertainment) ---> ['Sales Manager', 'Data Scientist', 'Marketing Specialist', 'HR Manager']
#  (Technology) ---> ['Software Engineer', 'Operations Manager', 'Cybersecurity Analyst', 'Data Scientist']
#  (Retail) ---> ['HR Manager', 'Sales Manager']
#  (Education) ---> ['AI Researcher', 'Data Scientist', 'UX Designer', 'HR Manager']
#  (Finance) ---> ['Sales Manager', 'Cybersecurity Analyst', 'Marketing Specialist', 'Product Manager', 'HR Manager']
#  (Transportation) ---> ['Product Manager', 'UX Designer', 'Software Engineer', 'AI Researcher', 'Sales Manager']
#  (Telecommunications) ---> ['Product Manager']
#  (Manufacturing) ---> ['Product Manager', 'Sales Manager', 'Marketing Specialist', 'HR Manager', 'UX Designer', 'Cybersecurity Analyst']
#  (Healthcare) ---> ['Marketing Specialist', 'Software Engineer', 'HR Manager', 'UX Designer', 'Data Scientist', 'Operations Manager']
#  (Energy) ---> ['Marketing Specialist', 'HR Manager']
#
#
# in **Sydney**
#  (Entertainment) ---> ['Data Scientist', 'Product Manager', 'UX Designer', 'Software Engineer', 'AI Researcher']
#  (Technology) ---> ['Marketing Specialist', 'Operations Manager', 'Data Scientist', 'UX Designer', 'Software Engineer']
#  (Retail) ---> ['Sales Manager', 'Software Engineer', 'Data Scientist', 'Marketing Specialist', 'Cybersecurity Analyst']
#  (Education) ---> ['Data Scientist', 'AI Researcher', 'Operations Manager', 'UX Designer']
#  (Finance) ---> ['Data Scientist', 'Product Manager', 'AI Researcher']
#  (Transportation) ---> ['Sales Manager', 'Cybersecurity Analyst', 'UX Designer']
#  (Telecommunications) ---> ['HR Manager', 'Data Scientist', 'Product Manager', 'Sales Manager', 'Cybersecurity Analyst']
#  (Manufacturing) ---> ['AI Researcher', 'HR Manager', 'Cybersecurity Analyst', 'Product Manager', 'Sales Manager', 'Data Scientist', 'Operations Manager']
#  (Healthcare) ---> ['Cybersecurity Analyst', 'Software Engineer', 'Operations Manager', 'UX Designer']
#  (Energy) ---> ['Marketing Specialist', 'Product Manager', 'UX Designer', 'Data Scientist']
#
#
# in **New York**
#  (Entertainment) ---> ['Operations Manager', 'Data Scientist', 'HR Manager', 'Marketing Specialist']
#  (Technology) ---> ['UX Designer', 'Operations Manager', 'AI Researcher', 'Product Manager', 'Software Engineer']
#  (Retail) ---> ['AI Researcher', 'Cybersecurity Analyst', 'Sales Manager', 'Software Engineer']
#  (Education) ---> ['AI Researcher', 'UX Designer', 'Cybersecurity Analyst', 'Data Scientist', 'Operations Manager']
#  (Finance) ---> ['AI Researcher', 'Product Manager', 'Sales Manager']
#  (Transportation) ---> ['Data Scientist']
#  (Telecommunications) ---> ['Cybersecurity Analyst', 'Software Engineer', 'Operations Manager', 'UX Designer', 'AI Researcher']
#  (Manufacturing) ---> ['Data Scientist', 'HR Manager', 'Software Engineer', 'Marketing Specialist', 'Sales Manager', 'UX Designer']
#  (Healthcare) ---> ['Cybersecurity Analyst']
#  (Energy) ---> ['HR Manager', 'Cybersecurity Analyst', 'Data Scientist']
#
#
# in **Toronto**
#  (Entertainment) ---> ['AI Researcher', 'Data Scientist']
#  (Technology) ---> ['AI Researcher', 'Cybersecurity Analyst', 'Sales Manager', 'Data Scientist']
#  (Retail) ---> ['Marketing Specialist', 'UX Designer', 'HR Manager']
#  (Education) ---> ['HR Manager', 'UX Designer', 'Product Manager', 'Cybersecurity Analyst']
#  (Finance) ---> ['AI Researcher', 'Product Manager', 'HR Manager', 'Sales Manager', 'Operations Manager']
#  (Transportation) ---> ['AI Researcher', 'Product Manager', 'Software Engineer', 'Sales Manager']
#  (Telecommunications) ---> ['Sales Manager', 'Data Scientist', 'Product Manager', 'UX Designer']
#  (Manufacturing) ---> ['Data Scientist', 'Software Engineer']
#  (Healthcare) ---> ['Cybersecurity Analyst']
#  (Energy) ---> ['HR Manager', 'AI Researcher', 'UX Designer', 'Sales Manager']

# %%
# Job_Title & Salary_USD & Industry
what is salary for each job in each industy ?

# %%
job_title_industry_group = job.groupby(['Industry' , 'Job_Title']) 
for industry in job.Industry.unique(): 
 for job_name in job.Job_Title.unique(): 
  print(f"Salary_USD in ({industry}) for ({job_name})") 
  print(job_title_industry_group.get_group((industry,job_name)).Salary_USD.describe()[['mean' ,'min' , 'max']]) 
  print('-------------------------------\n') 
  print('****************************************************\n****************************************************')
# Out:
# Salary_USD in (Entertainment) for (Cybersecurity Analyst)
# mean     91567.603734
# min      66782.590810
# max     125455.823500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Entertainment) for (Marketing Specialist)
# mean     81401.75316
# min      68323.78300
# max     107067.72890
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Entertainment) for (AI Researcher)
# mean    104512.728113
# min      78902.565740
# max     119754.540700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Entertainment) for (Sales Manager)
# mean    102609.673707
# min      92037.214130
# max     118957.228700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Entertainment) for (UX Designer)
# mean    71004.788655
# min     35963.297320
# max     89145.924110
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Entertainment) for (HR Manager)
# mean     93839.432752
# min      68764.378920
# max     135778.949800
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Entertainment) for (Product Manager)
# mean     99479.15637
# min      89454.20121
# max     108280.43920
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Entertainment) for (Software Engineer)
# mean    72361.692277
# min     61857.520100
# max     81307.098200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Entertainment) for (Data Scientist)
# mean    102101.263086
# min      78829.705160
# max     125421.918000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Entertainment) for (Operations Manager)
# mean    109031.049522
# min      92422.938040
# max     139078.066900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Technology) for (Cybersecurity Analyst)
# mean     90259.610885
# min      76873.812180
# max     118489.240300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Technology) for (Marketing Specialist)
# mean     95975.019026
# min      80669.001370
# max     112524.001700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Technology) for (AI Researcher)
# mean     97187.933948
# min      76527.537180
# max     117752.886100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Technology) for (Sales Manager)
# mean    79434.167083
# min     60216.997660
# max     91705.626360
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Technology) for (UX Designer)
# mean    82460.63712
# min     74766.23588
# max     88155.31591
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Technology) for (HR Manager)
# mean     82537.499772
# min      69869.734150
# max     102836.310600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Technology) for (Product Manager)
# mean     95350.346725
# min      82127.811250
# max     109105.509500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Technology) for (Software Engineer)
# mean     94878.233902
# min      73638.279010
# max     107677.224100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Technology) for (Data Scientist)
# mean     83975.354942
# min      47666.724780
# max     110711.665800
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Technology) for (Operations Manager)
# mean    103310.702299
# min      76940.840170
# max     132528.711800
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Retail) for (Cybersecurity Analyst)
# mean    73757.579703
# min     68665.577820
# max     76744.303970
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Retail) for (Marketing Specialist)
# mean     98126.627979
# min      48773.490880
# max     118237.530400
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Retail) for (AI Researcher)
# mean     81607.891052
# min      71374.648410
# max     102757.934800
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Retail) for (Sales Manager)
# mean    105636.318438
# min      93027.953760
# max     134822.691400
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Retail) for (UX Designer)
# mean     78833.817057
# min      41495.714440
# max     123992.648300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Retail) for (HR Manager)
# mean     96925.99011
# min      79805.39690
# max     112139.80830
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Retail) for (Product Manager)
# mean    127413.2675
# min     127413.2675
# max     127413.2675
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Retail) for (Software Engineer)
# mean     84917.527844
# min      52243.503210
# max     104018.514300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Retail) for (Data Scientist)
# mean     93059.583687
# min      73105.670760
# max     104747.462700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Retail) for (Operations Manager)
# mean    109899.6334
# min     109899.6334
# max     109899.6334
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Education) for (Cybersecurity Analyst)
# mean    86238.800004
# min     72671.587770
# max     96197.545690
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Education) for (Marketing Specialist)
# mean    107064.084825
# min     102925.947400
# max     109663.044200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Education) for (AI Researcher)
# mean     94943.999394
# min      80562.808110
# max     119961.891300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Education) for (Sales Manager)
# mean     87564.058175
# min      55906.059730
# max     112414.748900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Education) for (UX Designer)
# mean     93749.056087
# min      49877.395940
# max     121894.680100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Education) for (HR Manager)
# mean     88175.51552
# min      54010.72137
# max     126849.58090
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Education) for (Product Manager)
# mean     99148.050968
# min      78981.776350
# max     122682.699900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Education) for (Software Engineer)
# mean    69301.498615
# min     63064.751820
# max     75538.245410
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Education) for (Data Scientist)
# mean    102573.663193
# min      74767.081880
# max     129631.583300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Education) for (Operations Manager)
# mean     94561.842333
# min      72482.008450
# max     121912.196500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Finance) for (Cybersecurity Analyst)
# mean     94668.202775
# min      86742.408450
# max     102593.997100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Finance) for (Marketing Specialist)
# mean     92348.723517
# min      43343.243990
# max     155209.821600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Finance) for (AI Researcher)
# mean    101418.714499
# min      71529.492160
# max     126266.824100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Finance) for (Sales Manager)
# mean     88699.084278
# min      60437.058240
# max     114957.919200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Finance) for (UX Designer)
# mean     84699.11412
# min      41396.15746
# max     109986.59420
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Finance) for (HR Manager)
# mean     97296.338825
# min      56461.830520
# max     118980.604600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Finance) for (Product Manager)
# mean    105546.601839
# min      70448.757490
# max     128973.419200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Finance) for (Software Engineer)
# mean     93285.72789
# min      56076.41865
# max     138448.11080
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Finance) for (Data Scientist)
# mean     94626.734957
# min      67722.938010
# max     127434.956400
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Finance) for (Operations Manager)
# mean    73434.50431
# min     65470.35820
# max     83249.43428
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Transportation) for (Cybersecurity Analyst)
# mean    93942.35422
# min     86165.88172
# max     97849.30282
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Transportation) for (Marketing Specialist)
# mean    104854.9992
# min     104854.9992
# max     104854.9992
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Transportation) for (AI Researcher)
# mean     96340.559903
# min      72700.986970
# max     122683.905300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Transportation) for (Sales Manager)
# mean     90937.91224
# min      62276.84112
# max     129306.82920
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Transportation) for (UX Designer)
# mean    86240.389613
# min     73532.815910
# max     95762.524730
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Transportation) for (HR Manager)
# mean     74234.525535
# min      46867.986070
# max     101601.065000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Transportation) for (Product Manager)
# mean    66707.405775
# min     42486.679780
# max     86341.966860
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Transportation) for (Software Engineer)
# mean    79104.722444
# min     63722.770840
# max     99722.553800
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Transportation) for (Data Scientist)
# mean     78863.581274
# min      31969.526350
# max     119717.365500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Transportation) for (Operations Manager)
# mean     84414.169505
# min      46705.714990
# max     104922.019700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Telecommunications) for (Cybersecurity Analyst)
# mean     86775.68558
# min      33601.38136
# max     121897.10700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Telecommunications) for (Marketing Specialist)
# mean    91897.51840
# min     84511.19946
# max     96548.39543
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Telecommunications) for (AI Researcher)
# mean     98396.791815
# min      92841.116230
# max     103952.467400
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Telecommunications) for (Sales Manager)
# mean     92718.491576
# min      80636.344170
# max     117056.823500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Telecommunications) for (UX Designer)
# mean     94908.815694
# min      83278.520280
# max     107103.067300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Telecommunications) for (HR Manager)
# mean     82799.724808
# min      58952.450770
# max     116772.434700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Telecommunications) for (Product Manager)
# mean     98251.49561
# min      66566.60284
# max     133106.65500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Telecommunications) for (Software Engineer)
# mean     90866.833046
# min      62093.325470
# max     114267.628000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Telecommunications) for (Data Scientist)
# mean     86745.364399
# min      57499.280620
# max     130007.350200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Telecommunications) for (Operations Manager)
# mean     94180.11993
# min      59806.14481
# max     129293.90100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Manufacturing) for (Cybersecurity Analyst)
# mean     94241.07548
# min      84587.58841
# max     100288.01870
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Manufacturing) for (Marketing Specialist)
# mean     82402.190327
# min      60768.876450
# max     111093.326200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Manufacturing) for (AI Researcher)
# mean     98719.187617
# min      73394.896220
# max     115238.677500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Manufacturing) for (Sales Manager)
# mean     84775.918596
# min      61109.653260
# max     111093.331600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Manufacturing) for (UX Designer)
# mean     87848.253937
# min      63245.811520
# max     101648.962500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Manufacturing) for (HR Manager)
# mean    79012.961903
# min     55015.599140
# max     95957.898330
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Manufacturing) for (Product Manager)
# mean    80333.401553
# min     53450.512920
# max     98153.125070
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Manufacturing) for (Software Engineer)
# mean     82207.560748
# min      61884.905390
# max     106800.196500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Manufacturing) for (Data Scientist)
# mean     91147.635785
# min      73518.823170
# max     112457.279100
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Manufacturing) for (Operations Manager)
# mean     78971.764847
# min      41810.513580
# max     116713.117900
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Healthcare) for (Cybersecurity Analyst)
# mean     91923.58647
# min      51676.65641
# max     135566.66060
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Healthcare) for (Marketing Specialist)
# mean     86991.662156
# min      74977.478860
# max     105559.095500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Healthcare) for (AI Researcher)
# mean     92703.013875
# min      67469.063750
# max     117936.964000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Healthcare) for (Sales Manager)
# mean     93593.962637
# min      70845.835020
# max     107851.790300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Healthcare) for (UX Designer)
# mean    106019.748104
# min      86291.410650
# max     126678.453000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Healthcare) for (HR Manager)
# mean    101400.653645
# min      95217.781290
# max     107583.526000
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Healthcare) for (Product Manager)
# mean    66491.713203
# min     41298.726200
# max     99311.680330
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Healthcare) for (Software Engineer)
# mean    79270.986933
# min     45186.524270
# max     99835.926630
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Healthcare) for (Data Scientist)
# mean     96530.872623
# min      45848.725490
# max     148467.112300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Healthcare) for (Operations Manager)
# mean     96956.091812
# min      77642.150630
# max     111189.610600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Energy) for (Cybersecurity Analyst)
# mean     88025.462324
# min      79644.933100
# max     102999.231300
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Energy) for (Marketing Specialist)
# mean     77774.561498
# min      50286.756870
# max     101964.987500
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Energy) for (AI Researcher)
# mean     92999.981446
# min      71211.884320
# max     109264.899700
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Energy) for (Sales Manager)
# mean    108200.119646
# min      75497.338130
# max     124900.328600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Energy) for (UX Designer)
# mean    105484.278888
# min      83131.778010
# max     140475.995800
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Energy) for (HR Manager)
# mean     86944.595389
# min      61369.640050
# max     112822.654600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Energy) for (Product Manager)
# mean    75230.504445
# min     50697.988510
# max     85644.528350
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Energy) for (Software Engineer)
# mean    87667.40135
# min     87667.40135
# max     87667.40135
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Energy) for (Data Scientist)
# mean     87743.649354
# min      65884.757430
# max     127392.306600
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
# Salary_USD in (Energy) for (Operations Manager)
# mean    112766.46766
# min     101019.73320
# max     129825.05200
# Name: Salary_USD, dtype: float64
# -------------------------------
#
# ****************************************************
# ****************************************************
